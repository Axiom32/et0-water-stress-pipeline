# %%
git add requirements.txt
git commit -m "Install Python dependencies via pip"
git push origin main
# Out:
#   Cell In[1], line 1
#     git add requirements.txt
#         ^
# SyntaxError: invalid syntax
